# %% [markdown]
# # DS-NN · <Author (year)> — <Title>
#
# **Tier:** ...
#
# ### 📋 Brief
# ...

# %% [markdown]
# ### ✅ Rubric — Definition of Done
# 1. ...
# 2. ...

# %% [markdown]
# ## Setup

# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt

# %% [markdown]
# ## Task 1 — ...

# %%
# TODO
