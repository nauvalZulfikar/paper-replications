# %% [markdown]
# # DS-NN · <Author (year)> — <Title>
#
# **Tier:** ...
#
# ### 📋 Brief
# <konteks paper, bahasa manusia>
#
# ### 🧠 Intuisi
# <analogi sebelum kode>

# %% [markdown]
# ### ✅ Rubric — Definition of Done
# | # | Yang harus ada | Lulus kalau |
# |---|---|---|
# | 1 | ... | ... |

# %% [markdown]
# ### ⚠️ Aturan main
# - Lu yang ngetik kodenya; gua jelasin konsep+rumus+langkah, bukan solusi jadi.

# %% [markdown]
# ## 🔧 Setup

# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt

def cek(nama, got, lo, hi, kalau_salah=''):
    """Self-check: cetak OK kalau `got` masuk rentang target. Bukan penilai, cuma rambu."""
    ok = lo <= got <= hi
    print(f"{'OK ' if ok else 'X  '} {nama} = {got:.4f}   (target {lo}-{hi})")
    if not ok and kalau_salah:
        print(f'    -> {kalau_salah}')

# %% [markdown]
# ## Task 1 — ...
# ### 🧠 Konsep
# ...
# ### 📐 Rumus
# ...
# ### 🪜 Langkah kecil
# 1. ...

# %%
# Task 1 — isi TODO
# ...

# self-check
# cek('<nama>', <var>, <lo>, <hi>, '<tersangka kalau meleset>')
